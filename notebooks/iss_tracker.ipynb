# %%
import requests
import plotly.express as px
import datetime as dt
import os

print("✅ Imports OK")
print("Current folder:", os.getcwd())
print("Figures folder exists?", os.path.exists("../figures"))
# Out:
# ✅ Imports OK
# Current folder: /Users/tinashe/Documents/iss-tracker/notebooks
# Figures folder exists? True

# %%
# Get live ISS position
response = requests.get("http://api.open-notify.org/iss-now.json")
data = response.json()

timestamp = dt.datetime.fromtimestamp(data["timestamp"])
lat = float(data["iss_position"]["latitude"])
lon = float(data["iss_position"]["longitude"])

print(f"🛰 ISS at {timestamp}: lat={lat}, lon={lon}")
# Out:
# 🛰 ISS at 2026-03-08 11:00:31: lat=-41.2004, lon=-28.9429

# %%
fig = px.scatter_geo(lat=[lat], lon=[lon], projection="natural earth",
                     title="Live ISS Position")
fig.update_traces(marker=dict(size=15, color="red"))
fig.show()

fig.write_image("../figures/iss_live.png", width=1200, height=600)
print("✅ Saved iss_live.png")
# Out:
# ✅ Saved iss_live.png

# %%
# Get current ISS crew
response = requests.get("http://api.open-notify.org/astros.json")
crew = response.json()["people"]
print(f"👨‍🚀 {len([p for p in crew if p['craft'] == 'ISS'])} astronauts on ISS:")
for person in crew:
    if person["craft"] == "ISS":
        print(f"• {person['name']}")
# Out:
# 👨‍🚀 9 astronauts on ISS:
# • Oleg Kononenko
# • Nikolai Chub
# • Tracy Caldwell Dyson
# • Matthew Dominick
# • Michael Barratt
# • Jeanette Epps
# • Alexander Grebenkin
# • Butch Wilmore
# • Sunita Williams

# %%
# Cell 4: Fix PNG export (run once)
import sys
# !{sys.executable} -m pip install kaleido --force-reinstall --no-cache-dir --upgrade pip

print("🔄 Kaleido reinstalled. RESTART KERNEL NOW:")
print("Cmd+Shift+P → 'Jupyter: Restart Kernel'")
print("Then re-run Cells 1-3 → PNGs will work!")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 39.4 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 122.3 MB/s  0:00:00
# ...
#   Attempting uninstall: simplejson
#     Found existing installation: simplejson 3.20.2
#     Uninstalling simplejson-3.20.2:
#       Successfully uninstalled simplejson-3.20.2
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.19.2
#     Uninstalling Pygments-2.19.2:
#       Successfully uninstalled Pygments-2.19.2
#   Attempting uninstall: pluggy━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/12 [pygments]
#     Found existing installation: pluggy 1.6.0━━━━━━━━━━━━━━━━━  1/12 [pygments]
#     Uninstalling pluggy-1.6.0:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/12 [pygments]
#       Successfully uninstalled pluggy-1.6.0━━━━━━━━━━━━━━━━━━━  1/12 [pygments]
#   Attempting uninstall: pip━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/12 [pygments]
#     Found existing installation: pip 26.0.1━━━━━━━━━━━━━━━━━━━  1/12 [pygments]
# ...

# %%
# Simple trail: ISS + nearby points
fig = px.scatter_geo(
    lat=[lat-0.1, lat, lat+0.1], 
    lon=[lon-0.1, lon, lon+0.1],
    projection="natural earth",
    title="ISS + Orbit Approximation"
)
fig.update_traces(marker=dict(size=[8,15,8], color="orange"))
fig.show()
fig.write_image("../figures/iss_orbit.png")
print("✅ Orbit saved")
# Out:
# ✅ Orbit saved
